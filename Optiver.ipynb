# %% [markdown]
# <a href="https://colab.research.google.com/github/YaokunLin/ActuaryProgrammer/blob/main/Optiver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
https://www.1point3acres.com/interview/problems/company/optiver/proportional-allocation-backtest

'''

# %%
def performance(prices):
  n_stocks = len(prices)
  n_days = len(prices[0])
  allocations = [[0] * n_days] * n_stocks

  for d in range(1, n_days):
    non_neg_stock_returns_day_d = [0] * n_stocks
    for s in range(n_stocks):
      non_neg_stock_returns_day_d[s] = max(
          (prices[s][d] - prices[s][d-1]) / prices[s][d-1],
          0)

    sum_non_neg_stock_returns_day_d = sum(non_neg_stock_returns_day_d)
    for s in range(n_stocks):
      allocations[s][d] = non_neg_stock_returns_day_d[s] / sum_non_neg_stock_returns_day_d




  return [port_avg_daily_log_returns, port_sd_daily_log_returns]
